# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:/Users/delve/OneDrive/Eu/GitHub/PO-233-Aprendizado-de-Maquina/Pré-Processamento/Normalized_Data.csv', index_col=0)
data2 = pd.read_csv('C:/Users/delve/OneDrive/Eu/GitHub/PO-233-Aprendizado-de-Maquina/Pré-Processamento/Non_Normalized_Data.csv', index_col=0)
data
# Out:
#       Sales & Services Revenue   Gross Profit   Selling, General & Admin   \
# 0                      5.184228       3.270406                   1.836533
# 1                      4.354963       2.418717                   2.102237
# 2                      2.943363       1.942510                   1.789186
# 3                      0.607424      -0.217547                   0.438384
# 4                      0.458869       0.331974                   0.598252
# ...                         ...            ...                        ...
# 2529                  -0.105639       0.201103                   0.073528
# 2530                   0.064704      -0.154510                   0.949739
# 2531                   1.088741       0.610846                  -0.056817
# 2532                   0.258815       0.152455                   0.428357
# 2533                   0.225803       0.195964                   0.184377
#
#       Non-Operating (Income) Loss   Pretax Income   \
# 0                        -0.129995        0.374486
# 1                         0.415736        0.239319
# 2                         0.063895        0.178533
# 3                         0.301033       -0.028495
# 4                        -0.037722        0.018808
# ...                            ...             ...
# 2529                     -1.679849       -0.071776
# 2530                      0.032889       -0.072824
# 2531                     -0.069000        0.181621
# 2532                      0.041415       -0.002039
# 2533                     -0.002503        0.026597
#
#       Income (Loss) from Cont Ops   Basic Weighted Avg Shares   \
# 0                         0.684311                    0.281492
# 1                         0.399256                    0.249365
# 2                         0.286511                    0.174403
# 3                        -0.052849                   -0.154515
# 4                         0.031381                   -0.925558
# ...                            ...                         ...
# 2529                     -0.075539                   -0.760335
# 2530                     -0.141588                   -0.200410
# 2531                      0.348709                   -0.253955
# 2532                     -0.074552                   -0.566044
# 2533                      0.096443                   -0.267723
#
#       Basic EPS, GAAP   Diluted Weighted Avg Shares   Diluted EPS, GAAP   ...  \
# 0             0.694453                      0.294091            0.696380  ...
# 1             0.403307                      0.194553            0.408185  ...
# 2             0.290998                      0.140259            0.293974  ...
# 3            -0.050844                     -0.218683           -0.049152  ...
# 4             0.066579                     -0.922993            0.067331  ...
# ...                ...                           ...                 ...  ...
# 2529         -0.057531                     -0.732965           -0.058242  ...
# 2530         -0.143631                     -0.289567           -0.142121  ...
# 2531          0.379409                     -0.245830            0.380917  ...
# 2532         -0.062153                     -0.598739           -0.061206  ...
# 2533          0.111472                     -0.259403            0.111840  ...
#
#       Cash from Operating Activities   Acq of Fixed & Intang   \
# 0                            0.649951                0.702489
# 1                            0.796941                2.358583
# 2                            0.277935                0.245580
# 3                            0.043283               -0.032563
# 4                            0.088210                0.076198
# ...                               ...                     ...
# 2529                         0.092515               -0.152397
# 2530                        -0.005948               -0.172385
# 2531                         0.240523                0.410551
# 2532                        -0.127971                0.199880
# 2533                         0.096506                0.020176
#
#       Cash from Investing Activities   Cash from Financing Activities   \
# 0                           -0.011974                         0.111563
# 1                            0.111835                         0.018530
# 2                            0.011268                        -0.270957
# 3                           -0.017480                         1.076669
# 4                           -0.019334                         0.160951
# ...                               ...                              ...
# 2529                        -0.074724                        -0.079946
# 2530                         0.163702                        -0.026549
# 2531                        -0.028205                         0.173627
# 2532                         0.009775                        -0.031294
# 2533                        -0.027430                         0.009975
#
#       Net Changes in Cash   Capital Expenditures   Free Cash Flow   \
# 0                -0.053267               0.702489         0.281841
# 1                -0.034665               2.358583         0.276550
# 2                -0.045913               0.245580         0.126703
# 3                 0.077464              -0.032563         0.025354
# 4                -0.031230               0.076198         0.039890
# ...                    ...                    ...              ...
# 2529             -0.035068              -0.152397         0.062933
# 2530             -0.005508              -0.172385         0.007770
# 2531             -0.056103               0.410551         0.096828
# 2532             -0.016234               0.199880        -0.074421
# 2533             -0.047028               0.020176         0.049603
#
#       Price/Free Cash Flow   Cash Flow to Net Income   Performance
# 0                 -0.036114                 -0.077416     1.678843
# 1                 -0.103958                  0.027638     1.065240
# 2                  0.088897                 -0.048077     0.798523
# 3                 -0.092919                  0.057431    -0.897314
# 4                  0.070369                  0.013060     1.218211
# ...                     ...                       ...          ...
# 2529              -0.007295                  0.100983    -0.727777
# 2530               0.025712                  0.127710    -0.267209
# 2531              -0.014562                 -0.075836     0.131783
# 2532               0.005658                 -0.001731     0.560620
# 2533              -0.029540                 -0.020652    -0.845843
#
# [2272 rows x 55 columns]

# %%
desc_stats = data.describe()
desc_stats
# Out:
#        Sales & Services Revenue   Gross Profit   Selling, General & Admin   \
# count                2272.000000    2272.000000                2272.000000
# mean                    0.474749       0.282855                   0.306336
# std                     1.000000       1.000000                   1.000000
# min                    -5.054160     -10.993169                 -10.272778
# 25%                     0.028225       0.009764                  -0.010166
# 50%                     0.419915       0.227997                   0.293834
# 75%                     0.853694       0.490424                   0.583351
# max                     7.611281      12.334427                  12.458013
#
#        Non-Operating (Income) Loss   Pretax Income   \
# count                   2272.000000     2272.000000
# mean                      -0.038275        0.041099
# std                        1.000000        1.000000
# min                      -11.153056      -24.199710
# 25%                       -0.140510       -0.027157
# 50%                       -0.012727        0.023878
# 75%                        0.078803        0.075274
# max                       10.905210       27.718144
#
#        Income (Loss) from Cont Ops   Basic Weighted Avg Shares   \
# count                   2272.000000                 2272.000000
# mean                       0.072246                   -0.043176
# std                        1.000000                    1.000000
# min                      -12.003276                   -8.048533
# 25%                       -0.056102                   -0.394701
# 50%                        0.042420                   -0.107089
# 75%                        0.143902                    0.094851
# max                       14.652016                   13.849718
#
#        Basic EPS, GAAP   Diluted Weighted Avg Shares   Diluted EPS, GAAP   \
# count       2272.000000                   2272.000000         2272.000000
# mean           0.061909                     -0.047287            0.062302
# std            1.000000                      1.000000            1.000000
# min          -13.869338                     -7.913311          -14.041758
# 25%           -0.060715                     -0.408711           -0.060218
# 50%            0.050081                     -0.119145            0.050165
# 75%            0.156686                      0.087850            0.156595
# max           14.578099                     13.680512           14.679106
#
#        ...  Cash from Operating Activities   Acq of Fixed & Intang   \
# count  ...                      2272.000000             2272.000000
# mean   ...                         0.046804                0.174374
# std    ...                         1.000000                1.000000
# min    ...                       -20.794834               -0.936526
# 25%    ...                        -0.069621               -0.058885
# 50%    ...                         0.059172                0.074978
# 75%    ...                         0.186086                0.230566
# max    ...                        10.566401               30.511523
#
#        Cash from Investing Activities   Cash from Financing Activities   \
# count                      2272.000000                      2272.000000
# mean                         -0.017900                        -0.031969
# std                           1.000000                         1.000000
# min                         -30.721888                       -13.742766
# 25%                          -0.036578                        -0.123101
# 50%                          -0.002686                        -0.028211
# 75%                           0.031426                         0.049057
# max                          10.906489                        12.996266
#
#        Net Changes in Cash   Capital Expenditures   Free Cash Flow   \
# count           2272.000000            2272.000000      2272.000000
# mean              -0.021387               0.174374         0.059329
# std                1.000000               1.000000         1.000000
# min              -18.741803              -0.936526        -8.898417
# 25%               -0.056221              -0.058885        -0.060295
# 50%               -0.031223               0.074978         0.018622
# 75%               -0.003967               0.230566         0.105402
# max               24.652942              30.511523        19.580390
#
#        Price/Free Cash Flow   Cash Flow to Net Income   Performance
# count            2272.000000               2272.000000  2272.000000
# mean                0.006395                 -0.002838     0.230922
# std                 1.000000                  1.000000     1.000000
# min               -25.993002                -10.674926    -3.037691
# 25%                -0.041585                 -0.082556    -0.400366
# 50%                 0.011012                 -0.013318     0.160997
# 75%                 0.065695                  0.056118     0.750649
# max                23.660482                 17.702000     5.773567
#
# [8 rows x 55 columns]

# %%
desc_stats = data2.describe()
desc_stats
# Out:
#        Sales & Services Revenue   Gross Profit   Selling, General & Admin   \
# count                2534.000000    2534.000000                2534.000000
# mean                    8.816361      11.182174                   7.469092
# std                    27.058834      70.872749                  43.545487
# min                   -76.550000    -949.900000                -405.000000
# 25%                     0.572500       0.252500                  -0.250000
# 50%                     6.520000       6.770000                   5.275000
# 75%                    13.542500      14.850000                  11.122500
# max                   883.910000    1656.000000                1162.750000
#
#        Non-Operating (Income) Loss   Pretax Income   \
# count                   2534.000000     2534.000000
# mean                      -9.590071       68.530422
# std                      904.600502     2449.394232
# min                   -11750.000000    -8543.550000
# 25%                      -59.750000      -10.755000
# 50%                       -5.650000        8.220000
# 75%                       33.960000       26.585000
# max                    20881.080000   121600.000000
#
#        Income (Loss) from Cont Ops   Basic Weighted Avg Shares   \
# count                   2534.000000                 2534.000000
# mean                      29.063796                    0.626507
# std                      628.357117                   25.795297
# min                    -8555.000000                  -52.610000
# 25%                      -13.607500                   -2.560000
# 50%                        8.660000                   -0.670000
# 75%                       30.805000                    0.680000
# max                    23396.590000                 1217.400000
#
#        Basic EPS, GAAP   Diluted Weighted Avg Shares   Diluted EPS, GAAP   \
# count       2534.000000                   2534.000000         2534.000000
# mean          10.025391                      0.551511           10.088453
# std         1348.991541                     25.606444         1347.274101
# min       -56902.600000                    -52.470000       -56818.950000
# 25%          -14.430000                     -2.700000          -14.205000
# 50%            9.710000                     -0.770000            9.720000
# 75%           32.060000                      0.670000           32.105000
# max        24687.850000                   1216.850000        24787.520000
#
#        ...  Cash from Operating Activities   Acq of Fixed & Intang   \
# count  ...                      2534.000000             2534.000000
# mean   ...                         4.051622               62.776661
# std    ...                       661.753905             1352.264840
# min    ...                    -27477.780000              -99.800000
# 25%    ...                        -9.070000               -6.737500
# 50%    ...                         7.680000                7.990000
# 75%    ...                        25.355000               24.815000
# max    ...                     10978.110000            59500.000000
#
#        Cash from Investing Activities   Cash from Financing Activities   \
# count                     2.534000e+03                      2534.000000
# mean                      1.119564e+03                      -114.995454
# std                       6.429971e+04                      2742.624116
# min                      -2.974651e+05                    -64189.960000
# 25%                      -6.288000e+01                      -101.787500
# 50%                      -4.205000e+00                       -22.900000
# 75%                       5.609500e+01                        39.962500
# max                       3.221723e+06                     52810.270000
#
#        Net Changes in Cash   Capital Expenditures   Free Cash Flow   \
# count          2.534000e+03            2534.000000      2534.000000
# mean           2.268845e+03              62.776661         2.742123
# std            8.913396e+04            1352.264840      1356.737920
# min           -1.062333e+05             -99.800000    -51500.000000
# 25%           -2.015325e+02              -6.737500       -18.797500
# 50%           -1.112200e+02               7.990000         5.540000
# 75%           -8.335000e+00              24.815000        32.065000
# max            4.032421e+06           59500.000000     22921.430000
#
#        Price/Free Cash Flow   Cash Flow to Net Income   Performance
# count            2534.000000               2534.000000  2534.000000
# mean              -19.176476                 42.840998     0.060224
# std              9507.472384               1376.114023     0.268959
# min           -362738.130000             -14486.010000    -0.728918
# 25%               -16.410000                -28.990000    -0.098728
# 50%                 3.840000                 -4.625000     0.038732
# 75%                23.827500                 19.910000     0.184700
# max            311564.330000              54271.770000     2.855869
#
# [8 rows x 55 columns]

# %%
# Plotar histogramas para as primeiras 10 colunas
data.iloc[:, 1:11].hist(figsize=(20, 10), bins=110)
plt.suptitle('Distribuição das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar histogramas para as primeiras 10 colunas
data.iloc[:, 11:21].hist(figsize=(20, 10), bins=110)
plt.suptitle('Distribuição das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar histogramas para as primeiras 10 colunas
data.iloc[:, 21:31].hist(figsize=(20, 10), bins=110)
plt.suptitle('Distribuição das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar histogramas para as primeiras 10 colunas
data.iloc[:, 31:41].hist(figsize=(20, 10), bins=110)
plt.suptitle('Distribuição das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar histogramas para as primeiras 10 colunas
data.iloc[:, 41:51].hist(figsize=(20, 10), bins=110)
plt.suptitle('Distribuição das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar histogramas para as primeiras 10 colunas
data.iloc[:, 51:61].hist(figsize=(20, 10), bins=110)
plt.suptitle('Distribuição das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar boxplots para as primeiras 10 colunas
data.iloc[:, 1:11].plot(kind='box', figsize=(25, 10))
plt.title('Boxplots das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar boxplots para as primeiras 10 colunas
data.iloc[:, 11:21].plot(kind='box', figsize=(25, 10))
plt.title('Boxplots das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar boxplots para as primeiras 10 colunas
data.iloc[:,21:31].plot(kind='box', figsize=(25, 10))
plt.title('Boxplots das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar boxplots para as primeiras 10 colunas
data.iloc[:, 31:41].plot(kind='box', figsize=(25, 10))
plt.title('Boxplots das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar boxplots para as primeiras 10 colunas
data.iloc[:, 41:51].plot(kind='box', figsize=(25, 10))
plt.title('Boxplots das Primeiras 10 Variáveis')
plt.show()

# %%
# Plotar boxplots para as primeiras 10 colunas
data.iloc[:, 51:61].plot(kind='box', figsize=(25, 10))
plt.title('Boxplots das Primeiras 10 Variáveis')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular a matriz de correlação
correlation_matrix = data.corr()

# Selecionar a coluna 'Performance' para ver as correlações específicas
performance_correlation = correlation_matrix['Performance'].sort_values(ascending=False)

# Visualizar as 10 variáveis mais correlacionadas
top_10_correlated = performance_correlation  # incluindo 'Performance' em si

# Plotar as correlações
plt.figure(figsize=(10, 8))
sns.barplot(x=top_10_correlated.index, y=top_10_correlated.values)
plt.title('Variáveis Mais Correlacionadas com a Performance Relativa')
plt.xlabel('Variáveis')
plt.ylabel('Correlação de Pearson')
plt.xticks(rotation=90)
plt.show()
