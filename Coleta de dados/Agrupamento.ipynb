# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df1 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_AAPL.csv')
df2 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_ABT.csv')
df3 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_ADBE.csv')
df4 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_AES.csv')
df5 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_ALL.csv')
df6 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_AMD.csv')
df7 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_AOS.csv')
df8 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_AXP.csv')
df9 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_GOOGL.csv')
df10 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_JPM.csv')
df11 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_MMM.csv')
df12 = pd.read_csv('C:\\Users\\delve\\OneDrive\\Eu\\GitHub\\PO-233-Aprendizado-de-Maquina\\Coleta de dados\\Data\\Data_MSFT.csv')

df5
# Out:
#          Date   Sales & Services Revenue   Cost of Revenue   Gross Profit   \
# 0     0   2010                      -1.91  - -                       -1.91
# 1     1   2011                       3.99  - -                        3.99
# 2     2   2012                       2.02  - -                        2.02
# 3     3   2013                       3.58  - -                        3.58
# 4     4   2014                       2.12  - -                        2.12
# 5     5   2015                       1.17  - -                        1.17
# 6     6   2016                       2.47  - -                        4.90
# 7     7   2017                       5.45  - -                        5.37
# 8     8   2018                       3.35  - -                        1.04
# 9     9   2019                      12.21  - -                        4.34
# 10   10   2020                       0.26  - -                        0.89
# 11   11   2021                      12.94  - -                       20.74
# 12   12   2022                       1.63  - -                        1.60
# 13   13   2023                      11.05  - -                       11.05
#
#       Selling, General & Admin   Research & Development   \
# 0   - -                          - -
# 1   - -                          - -
# 2   18.74                        - -
# 3   6.53                         - -
# 4   -1.05                        - -
# 5   -5.99                        - -
# 6   0.61                         - -
# 7   13.44                        - -
# 8   -89.95                       - -
# 9   -75.64                       - -
# 10  -144.74                      - -
# 11  1162.75                      - -
# 12  -118.01                      - -
# 13  -92.24                       - -
#
#     Operating Income (Loss)   Non-Operating (Income) Loss   Pretax Income   \
# 0   - -                                              -9.78           -9.78
# 1   - -                                             -14.74          -14.74
# 2   - -                                             244.38          244.38
# 3   - -                                               2.72            2.72
# 4   - -                                              24.73           24.73
# 5   - -                                             -22.52          -22.52
# 6   - -                                             -16.09          -16.09
# 7   - -                                              44.92           44.92
# 8   - -                                             -34.15          -34.15
# 9   - -                                             131.70          131.70
# 10  - -                                              14.29           14.29
# 11  - -                                              -7.34           -7.34
# 12  - -                                            -128.82         -128.82
# 13  - -                                             -81.27          -81.27
#
#     ...  Dividends Paid   Cash From Debt   Cash (Repurchase) of Equity   \
# 0   ...           -20.66  - -                                  12300.00
# 1   ...             1.16  -99.3                                  653.23
# 2   ...            22.76  6942.86                                 -2.25
# 3   ...           -32.96  360.65                                 100.88
# 4   ...            57.54  - -                                     25.46
# 5   ...             6.21  - -                                     22.03
# 6   ...             0.50  -45.57                                 -52.39
# 7   ...             6.48  - -                                     11.82
# 8   ...            16.69  -59.71                                  54.05
# 9   ...             5.21  -1.41                                  -24.66
# 10  ...            -1.40  142.16                                   0.12
# 11  ...            28.74  - -                                     79.62
# 12  ...             3.20  - -                                    -19.23
# 13  ...             0.10  -37.51                                 -86.71
#
#     Cash from Financing Activities   Net Changes in Cash   \
# 0                            -19.53               -125.38
# 1                             29.73               -528.00
# 2                            -41.53                -85.98
# 3                             29.27               -536.67
# 4                            -18.11                -86.26
# 5                             -7.28                800.00
# 6                            -66.24                -63.58
# 7                             91.55               -406.78
# 8                             22.27               -165.19
# 9                            -30.53                 36.44
# 10                           -19.01               -124.22
# 11                           160.57                889.74
# 12                           -34.73               -106.99
# 13                           -63.65                -48.15
#
#     Capital Expenditures   Free Cash Flow  Price/Free Cash Flow   \
# 0                  -14.29           -14.23                 21.53
# 1                   51.85           -52.28                 47.92
# 2                   15.85            64.53                -11.33
# 3                  -27.37            45.72                 -2.09
# 4                   39.13           -26.94                 54.10
# 5                    5.21            12.38                -26.54
# 6                    3.30            11.08                  0.48
# 7                   -4.47             9.10                 28.24
# 8                   -7.36            21.99                -36.39
# 9                   56.32            -4.12                 25.85
# 10                 -28.87            10.37                -12.23
# 11                  12.01            -7.95                  9.43
# 12                  21.74            -1.47                  3.16
# 13                 -36.43           -15.74                 22.92
#
#    Cash Flow to Net Income  Performance
# 0                    -21.07   -0.037496
# 1                    -38.42   -0.113562
# 2                    -45.90    0.368281
# 3                     40.48    0.089832
# 4                    -38.97    0.198428
# 5                     46.69   -0.092200
# 6                     27.72    0.121889
# 7                    -36.41    0.242246
# 8                     77.11   -0.132829
# 9                    -55.83    0.099432
# 10                    -6.94   -0.163757
# 11                   224.90   -0.170282
# 12                  -222.09    0.378174
# 13                   475.74   -0.178610
#
# [14 rows x 78 columns]

# %%
df_combinado = pd.concat([df1, df2, df3, df5, df6, df7, df8, df9, df10, df11, df12], axis = 0, ignore_index=True)
df_combinado = df_combinado.drop(df_combinado.columns[0], axis=1)
df_combinado = df_combinado.drop(df_combinado.columns[77], axis=1)
df_combinado = df_combinado.drop(df_combinado.columns[79], axis=1)
df_combinado = df_combinado.drop(df_combinado.columns[78], axis=1)
df_combinado = df_combinado.drop(df_combinado.columns[77], axis=1)
df_combinado = df_combinado.drop(df_combinado.columns[77], axis=1)
df_combinado = df_combinado.drop(df_combinado.columns[77], axis=1)

df_combinado.to_csv('saida.csv', index=True)
df_combinado
# Out:
#      Date   Sales & Services Revenue  Cost of Revenue   Gross Profit   \
# 0     2010                      78.52             69.0          95.46
# 1     2011                      65.96            62.95          70.60
# 2     2012                      44.58            36.34          56.70
# 3     2013                       9.20            21.36          -6.35
# 4     2014                       6.95              5.3           9.69
# ..     ...                        ...              ...            ...
# 149   2019                      14.03            11.88          15.17
# 150   2020                      13.65             7.38          16.89
# 151   2021                      17.53            13.36          19.52
# 152   2022                      17.96            19.95          17.06
# 153   2023                       6.88             5.13           7.69
#
#     Selling, General & Admin  Research & Development   \
# 0                       32.97                   33.68
# 1                       37.74                   36.31
# 2                       32.12                   39.19
# 3                        7.87                   32.36
# 4                       10.74                   34.99
# ..                        ...                     ...
# 149                      3.94                    14.6
# 150                      6.97                   14.18
# 151                      2.08                    7.51
# 152                      9.92                   18.32
# 153                      9.41                   10.95
#
#     Operating Income (Loss)   Non-Operating (Income) Loss   Pretax Income   \
# 0                     140.08                        -52.45          132.21
# 1                      83.79                        167.74           84.49
# 2                      63.48                         25.78           63.03
# 3                      -11.3                        121.46          -10.06
# 4                       7.15                        -15.22            6.64
# ..                       ...                           ...             ...
# 149                    22.54                        -48.52           19.78
# 150                    23.28                        -89.44           21.40
# 151                    32.02                       1440.26           34.06
# 152                    19.26                        -71.92           17.74
# 153                     6.16                        136.64            6.68
#
#      Income (Loss) from Cont Ops   ...  Dividends Paid   Cash From Debt   \
# 0                          145.67  ...  - -              - -
# 1                           84.99  ...  - -              - -
# 2                           60.99  ...  - -              - -
# 3                          -11.25  ...  324.6            - -
# 4                            6.68  ...  5.32             -29.21
# ..                            ...  ...              ...              ...
# 149                        136.80  ...             8.76  - -
# 150                         12.85  ...              9.6  - -
# 151                         38.37  ...             9.14  - -
# 152                         18.72  ...             9.77  - -
# 153                         -0.52  ...             9.18  - -
#
#      Cash (Repurchase) of Equity   Cash from Financing Activities   \
# 0                            92.0                            89.59
# 1                           -8.88                            14.88
# 2                          -19.98                          -217.59
# 3                        -3457.89                           864.61
# 4                           98.25                           129.25
# ..                            ...                              ...
# 149                         89.33                             9.82
# 150                         17.52                            24.79
# 151                         18.81                             5.33
# 152                          20.1                            21.43
# 153                        -33.95                           -25.38
#
#      Net Changes in Cash   Capital Expenditures  Free Cash Flow   \
# 0                 -190.71                  74.86           84.15
# 1                 -124.11                 251.34           82.57
# 2                 -164.38                  26.17           37.83
# 3                  277.34                  -3.47            7.57
# 4                 -111.81                   8.12           11.91
# ..                    ...                    ...             ...
# 149               -111.22                  19.71           18.63
# 150               -609.68                  10.89           18.23
# 151                -72.04                  33.55           24.06
# 152               -122.45                  15.83           16.09
# 153             -13894.08                  17.67           -8.71
#
#      Price/Free Cash Flow  Cash Flow to Net Income  Performance
# 0                   -13.02                   -25.49    0.402851
# 1                   -37.48                     9.10    0.255613
# 2                    32.05                   -15.83    0.191612
# 3                   -33.50                    18.91   -0.215317
# 4                    25.37                     4.30    0.292319
# ..                     ...                      ...         ...
# 149                  13.63                   -49.78    0.286801
# 150                  26.56                     3.03    0.262752
# 151                   5.90                    -8.59    0.255842
# 152                 -18.86                    -2.27   -0.085819
# 153                  27.09                    -1.12    0.339608
#
# [154 rows x 77 columns]
